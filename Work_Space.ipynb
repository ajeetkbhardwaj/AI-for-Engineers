# %% [markdown]
# <a href="https://colab.research.google.com/github/ajeetkbhardwaj/AI-for-Engineers/blob/main/Work_Space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step-0

# %%
# !dir
# Out:
# drive  sample_data

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks"
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !dir
# Out:
# Colab-100\ Image\ Classification\ with\ TensorFlow\ Lite.ipynb
# Copy\ of\ advanced_outputs.ipynb
# Copy\ of\ colab_starter\ (1).ipynb
# Copy\ of\ colab_starter.ipynb
# Copy\ of\ RNN_tutorial\ with\ solutions.ipynb
# Work-Space.ipynb

# %% [markdown]
# ## Step-1

# %%
# !git clone https://github.com/DS-4-DS/DS4DS_Course.git
# Out:
# Cloning into 'DS4DS_Course'...
# remote: Enumerating objects: 393, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 393 (delta 15), reused 11 (delta 5), pack-reused 354 (from 1)
# Receiving objects: 100% (393/393), 236.02 MiB | 12.97 MiB/s, done.
# Resolving deltas: 100% (133/133), done.
# Updating files: 100% (40/40), done.

# %%
# !git clone https://github.com/lunayht/AI504.git
# Out:
# Cloning into 'AI504'...
# remote: Enumerating objects: 266, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 266 (delta 17), reused 31 (delta 10), pack-reused 227 (from 1)
# Receiving objects: 100% (266/266), 153.40 MiB | 12.18 MiB/s, done.
# Resolving deltas: 100% (136/136), done.
# Updating files: 100% (43/43), done.

# %%
# !git clone --filter=blob:none --no-checkout https://github.com/Ceyron/machine-learning-and-simulation
# Out:
# Cloning into 'machine-learning-and-simulation'...
# remote: Enumerating objects: 1048, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 1048 (delta 162), reused 142 (delta 136), pack-reused 868 (from 2)
# Receiving objects: 100% (1048/1048), 114.24 KiB | 1.90 MiB/s, done.
# Resolving deltas: 100% (697/697), done.

# %%
# %cd machine-learning-and-simulation
# !dir
# Out:
# /content/drive/MyDrive/Colab Notebooks/machine-learning-and-simulation

# %%
# !git sparse-checkout init --cone

# %%
# !git sparse-checkout set english

# %%
# !git checkout
# Out:
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 201 (delta 5), reused 1 (delta 0), pack-reused 169 (from 2)
# Receiving objects: 100% (201/201), 96.73 MiB | 12.25 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# Updating files: 100% (202/202), done.
# Your branch is up to date with 'origin/main'.

# %% [markdown]
# ## Step-Last : Resources Reference
# [1]. https://mp2893.com/course.html
